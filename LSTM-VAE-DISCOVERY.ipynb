# %%
import torch

import copy
import numpy as np
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split

from torch import nn, optim

import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from arff2pandas import a2p


# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#ADFF02", "#8F00FF"]

sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))

rcParams['figure.figsize'] = 12, 8

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
with open('ECG5000/ECG5000_TRAIN.arff') as f:
    train = a2p.load(f)

with open('ECG5000/ECG5000_TEST.arff') as f:
    test = a2p.load(f)

# %%
df = train.append(test)
df.shape
# Out:
# (5000, 141)

# %%
CLASS_NORMAL = 1

class_names = ['Normal','R on T','PVC','SP','UB']

new_columns = list(df.columns)
new_columns[-1] = 'target'
df.columns = new_columns

# %%
df["target"].value_counts()
# Out:
# 1    2919
# 2    1767
# 4     194
# 3      96
# 5      24
# Name: target, dtype: int64

# %%
ax = sns.countplot(df.target)
ax.set_xticklabels(class_names);
# Out:
# /opt/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def plot_time_series_class(data, class_name, ax, n_steps=10):
    time_series_df = pd.DataFrame(data)

    smooth_path = time_series_df.rolling(n_steps).mean()
    path_deviation = 2 * time_series_df.rolling(n_steps).std()

    under_line = (smooth_path - path_deviation)[0]
    over_line = (smooth_path + path_deviation)[0]

    ax.plot(smooth_path, linewidth=2)
    ax.fill_between(
    path_deviation.index,
    under_line,
    over_line,
    alpha=.125
    )
    ax.set_title(class_name)

# %%
classes = df.target.unique()

fig, axs = plt.subplots(
  nrows=len(classes) // 3 + 1,
  ncols=3,
  sharey=True,
  figsize=(14, 8)
)

for i, cls in enumerate(classes):
    ax = axs.flat[i]
    data = df[df.target == cls] \
        .drop(labels='target', axis=1) \
        .mean(axis=0) \
        .to_numpy()
    plot_time_series_class(data, class_names[i], ax)

fig.delaxes(axs.flat[-1])
fig.tight_layout();

# %%
normal_df = df[df.target == str(CLASS_NORMAL)].drop(labels='target', axis=1)
normal_df.shape
# Out:
# (2919, 140)

# %%
anomaly_df = df[df.target != str(CLASS_NORMAL)].drop(labels='target', axis=1)
anomaly_df.shape
# Out:
# (2081, 140)

# %%
train_df, val_df = train_test_split(
  normal_df,
  test_size=0.15,
  random_state=RANDOM_SEED
)

val_df, test_df = train_test_split(
  val_df,
  test_size=0.33, 
  random_state=RANDOM_SEED
)

# %%
def create_dataset(df):

    sequences = df.astype(np.float32).to_numpy().tolist()

    dataset = [torch.tensor(s).unsqueeze(1).float() for s in sequences]

    n_seq, seq_len, n_features = torch.stack(dataset).shape

    return dataset, seq_len, n_features

# %%
train_dataset, seq_len, n_features = create_dataset(train_df)
val_dataset, _, _ = create_dataset(val_df)
test_normal_dataset, _, _ = create_dataset(test_df)
test_anomaly_dataset, _, _ = create_dataset(anomaly_df)

# %%
class Encoder(nn.Module):

    def __init__(self, seq_len, n_features, hidden_dim = 50, latent_features=16):
        super(Encoder, self).__init__()

        self.seq_len, self.n_features = seq_len, n_features
        self.latent_features = latent_features
        self.hidden_dim = hidden_dim

        self.lstm = nn.LSTM(
            input_size=self.n_features,
            hidden_size=self.hidden_dim,
            num_layers=1,
            batch_first=True
        )
        self.fc = nn.Linear(
            in_features=self.hidden_dim,
            out_features=2*latent_features)

    def forward(self, x):
        x = x.reshape((-1, self.seq_len, self.n_features))

        x, (hidden_n, _) = self.lstm(x)
        x = self.fc(hidden_n)

        return x.view(-1, 2*self.latent_features)

# %%
class Decoder(nn.Module):

    def __init__(self, seq_len, n_features=1, hidden_dim=50, latent_features=16):
        super(Decoder, self).__init__()

        self.seq_len = seq_len
        self.hidden_dim, self.n_features = hidden_dim, n_features
        
        self.latent_to_hidden = nn.Linear(
            latent_features,
            hidden_dim
        )


        self.lstm = nn.LSTM(
            input_size=hidden_dim,
            hidden_size=2 * seq_len,
            num_layers=1,
            batch_first=True
        )

    def forward(self, x):
        # (batch, 16) -> (batch, hidden)
        x = self.latent_to_hidden(x)
        
        # (batch, features, hidden)
        x = x.reshape(-1, n_features, self.hidden_dim)
        
        #(batch, features, hidden)
        x, (hidden_n, cell_n) = self.lstm(x)
        
        #(batch, features, 2*seq_len)
        return x.reshape(-1, 2*seq_len)

# %%
from torch import Tensor
from typing import Dict, Any, Tuple
from VAE.reparameterize import ReparameterizedDiagonalGaussian
from torch.distributions import Distribution


class BaseVAEprob(nn.Module):
    """A Variational Autoencoder with
    * a Bernoulli observation model `p_\theta(x | z) = B(x | g_\theta(z))`
    * a Gaussian prior `p(z) = N(z | 0, I)`
    * a Gaussian posterior `q_\phi(z|x) = N(z | \mu(x), \sigma(x))`
    """
    
    def __init__(self, latent_features:int, encoder, decoder, beta=1) -> None:
        super(BaseVAEprob, self).__init__()
        
        self.latent_features = latent_features
        self.beta=beta

        # Inference Network
        # Encode the observation `x` into the parameters of the posterior distribution
        # `q_\phi(z|x) = N(z | \mu(x), \sigma(x)), \mu(x),\log\sigma(x) = h_\phi(x)`
        self.encoder = encoder
        
        # Generative Model
        # Decode the latent sample `z` into the parameters of the observation model
        # `p_\theta(x | z) = \prod_i B(x_i | g_\theta(x))`
        # mu, sigma        
        self.decoder = decoder
        
        # define the parameters of the prior, chosen as p(z) = N(0, I)
        self.register_buffer('prior_params', torch.zeros(torch.Size([1, 2*latent_features])))
        
    def posterior(self, x:Tensor) -> Distribution:
        """return the distribution `q(x|x) = N(z | \mu(x), \sigma(x))`"""
        
        # compute the parameters of the posterior
        h_x = self.encoder(x)
        mu, log_sigma =  h_x.chunk(2, dim=-1)
        
        # return a distribution `q(x|x) = N(z | \mu(x), \sigma(x))`
        return ReparameterizedDiagonalGaussian(mu, log_sigma)
    
    def prior(self, batch_size:int=1)-> Distribution:
        """return the distribution `p(z)`"""
        prior_params = self.prior_params.expand(batch_size, *self.prior_params.shape[-1:])
        mu, log_sigma = prior_params.chunk(2, dim=-1)
        
        # return the distribution `p(z)`
        return ReparameterizedDiagonalGaussian(mu, log_sigma)
    
    def observation_model(self, z:Tensor) -> Distribution:
        """return the distribution `p(x|z)`"""
        z_tmp = self.decoder(z)
        mu, log_sigma =  z_tmp.chunk(2, dim=-1)
        return ReparameterizedDiagonalGaussian(mu, log_sigma)
        

    def forward(self, x) -> Dict[str, Any]:
        """compute the posterior q(z|x) (encoder), sample z~q(z|x) and return the distribution p(x|z) (decoder)"""
        
        # flatten the input
        x = x.view(x.size(0), -1)
        
        # define the posterior q(z|x) / encode x into q(z|x)
        qz = self.posterior(x)
        
        # define the prior p(z)
        pz = self.prior(batch_size=x.size(0))
        
        # sample the posterior using the reparameterization trick: z ~ q(z | x)
        z = qz.rsample()
        
        # define the observation model p(x|z) = B(x | g(z))
        px = self.observation_model(z)
        
        return {'px': px, 'pz': pz, 'qz': qz, 'z': z}
    
    
    def sample_from_prior(self, batch_size:int=100):
        """sample z~p(z) and return p(x|z)"""
        
        # degine the prior p(z)
        pz = self.prior(batch_size=batch_size)
        
        # sample the prior 
        z = pz.rsample()
        
        # define the observation model p(x|z) = B(x | g(z))
        px = self.observation_model(z)
        
        return {'px': px, 'pz': pz, 'z': z}

    def elbo(self, x:Tensor) -> Tuple[Tensor, Dict]:
        
        # forward pass through the model
        outputs = self.forward(x)
        
        # unpack outputs
        px, pz, qz, z = [outputs[k] for k in ["px", "pz", "qz", "z"]]
        
        # evaluate log probabilities
        log_px = px.log_prob(x.view(-1, int(decoder.seq_len))).view(px.size0, -1).sum(dim=1)
        log_pz = pz.log_prob(z).view(pz.size0, -1).sum(dim=1)
        log_qz = qz.log_prob(z).view(qz.size0, -1).sum(dim=1)
        
        # compute the ELBO with and without the beta parameter: 
        # `L^\beta = E_q [ log p(x|z) - \beta * D_KL(q(z|x) | p(z))`
        # where `D_KL(q(z|x) | p(z)) = log q(z|x) - log p(z)`

        kl = log_qz - log_pz
        elbo = log_px - kl
        beta_elbo = log_px - self.beta * kl
        
        # loss
        loss = -beta_elbo.mean()
        
        # prepare the output
        with torch.no_grad():
            diagnostics = {'elbo': elbo, 'log_px':log_px, 'kl': kl}
            
        return loss, diagnostics, outputs

# %%
encoder = Encoder(seq_len, n_features).to(device)
decoder = Decoder(seq_len)

# %%
model = BaseVAEprob(latent_features=16, encoder=encoder, decoder=decoder)

# %%
BATCH_SIZE = 64
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
validation_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
NUM_EPOCHS = 1000
LOSS_LIST = []
VAL_LOSS_LIST = []
for epoch in range(NUM_EPOCHS):
    running_loss = 0
    count = 0
    model.train()
    for batch in dat_loader:
        count += len(batch)/BATCH_SIZE
        batch = batch.to(device)

        loss, diagnostics, outputs = model.elbo(batch)
        running_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    avg_loss_epoch = running_loss/count
    LOSS_LIST.append(avg_loss_epoch)
    
    with torch.no_grad():
        model.eval()
        
        # Just load a single batch from the test loader
        x = next(iter(validation_loader))
        x = x.to(device)
        val_loss, _, _ = model.elbo(x)
    
    VAL_LOSS_LIST.append(val_loss.item())
    
    print(f"epoch {epoch+1}")
    print(f"Average loss: {avg_loss_epoch}")
    print(f"Validation loss: {val_loss}")
# Out:
# epoch 1
# Average loss: 182.76346994974304
# Validation loss: 131.2100372314453
# epoch 2
# Average loss: 109.87258575328748
# Validation loss: 99.73410034179688
# epoch 3
# Average loss: 95.69498678235843
# Validation loss: 96.62708282470703
# epoch 4
# Average loss: 92.48780891021765
# Validation loss: 85.77721405029297
# epoch 5
# Average loss: 91.18275022987203
# Validation loss: 82.10806274414062
# epoch 6
# Average loss: 90.63144822526199
# Validation loss: 91.36093139648438
# epoch 7
# Average loss: 90.04007330713422
# Validation loss: 87.16205596923828
# epoch 8
# Average loss: 88.24991360118148
# Validation loss: 82.57296752929688
# epoch 9
# Average loss: 86.28589073836154
# Validation loss: 82.80833435058594
# epoch 10
# Average loss: 84.80110165381902
# Validation loss: 81.57563781738281
# epoch 11
# Average loss: 84.69343790148882
# Validation loss: 80.44752502441406
# epoch 12
# Average loss: 83.61616783649487
# Validation loss: 83.13845825195312
# epoch 13
# Average loss: 83.90944754351824
# Validation loss: 84.61581420898438
# epoch 14
# Average loss: 83.02814102019096
# Validation loss: 83.9111557006836
# epoch 15
# Average loss: 82.62271958289249
# Validation loss: 79.87979888916016
# epoch 16
# Average loss: 82.38486383231307
# Validation loss: 82.02013397216797
# epoch 17
# Average loss: 82.11279021343461
# Validation loss: 88.35211181640625
# epoch 18
# Average loss: 81.66132509415306
# Validation loss: 77.84941101074219
# epoch 19
# Average loss: 81.54379003079656
# Validation loss: 83.3737564086914
# epoch 20
# Average loss: 81.41318571927901
# Validation loss: 81.76005554199219
# epoch 21
# Average loss: 81.3855922196191
# Validation loss: 79.80570220947266
# epoch 22
# Average loss: 81.28691847100464
# Validation loss: 79.81181335449219
# epoch 23
# Average loss: 80.44427000673872
# Validation loss: 80.73699951171875
# epoch 24
# Average loss: 80.16601444415055
# Validation loss: 79.4135971069336
# epoch 25
# Average loss: 80.24729250900594
# Validation loss: 81.5116195678711
# epoch 26
# Average loss: 79.59596271507205
# Validation loss: 80.2078857421875
# epoch 27
# Average loss: 79.60297361509976
# Validation loss: 82.31851959228516
# epoch 28
# Average loss: 79.13471504528164
# Validation loss: 81.35380554199219
# epoch 29
# Average loss: 79.19465063387999
# Validation loss: 79.34148406982422
# epoch 30
# Average loss: 79.06506539544287
# Validation loss: 78.77137756347656
# epoch 31
# Average loss: 78.758648738223
# Validation loss: 76.87201690673828
# epoch 32
# Average loss: 78.2086793222239
# Validation loss: 76.05298614501953
# epoch 33
# Average loss: 78.15504907610338
# Validation loss: 76.36805725097656
# epoch 34
# Average loss: 78.10362465676643
# Validation loss: 73.98614501953125
# epoch 35
# Average loss: 77.79378392974102
# Validation loss: 79.53014373779297
# epoch 36
# Average loss: 77.76697471092805
# Validation loss: 80.49652862548828
# epoch 37
# Average loss: 77.49589536729141
# Validation loss: 81.53441619873047
# epoch 38
# Average loss: 77.30846208528567
# Validation loss: 80.40837097167969
# epoch 39
# Average loss: 77.256548007041
# Validation loss: 76.19342041015625
# epoch 40
# Average loss: 76.62531371233878
# Validation loss: 74.72972869873047
# epoch 41
# Average loss: 76.45976098032547
# Validation loss: 75.74357604980469
# epoch 42
# Average loss: 75.92234025468561
# Validation loss: 76.1817855834961
# epoch 43
# Average loss: 75.78132734563935
# Validation loss: 74.8173599243164
# epoch 44
# Average loss: 76.02684661237907
# Validation loss: 73.21591186523438
# epoch 45
# Average loss: 75.21208902502771
# Validation loss: 76.16795349121094
# epoch 46
# Average loss: 75.05851640436065
# Validation loss: 71.43894958496094
# epoch 47
# Average loss: 74.59402513792321
# Validation loss: 72.37950134277344
# epoch 48
# Average loss: 74.38200912875352
# Validation loss: 76.2484130859375
# epoch 49
# Average loss: 73.97977303286225
# Validation loss: 74.82526397705078
# epoch 50
# Average loss: 73.90901102283605
# Validation loss: 70.04955291748047
# epoch 51
# Average loss: 73.48455606358323
# Validation loss: 70.91720581054688
# epoch 52
# Average loss: 73.56497506045949
# Validation loss: 77.396484375
# epoch 53
# Average loss: 73.62593857850916
# Validation loss: 72.0804214477539
# epoch 54
# Average loss: 73.59811579724658
# Validation loss: 70.5706558227539
# epoch 55
# Average loss: 73.19044720343359
# Validation loss: 70.46857452392578
# epoch 56
# Average loss: 73.07360687317362
# Validation loss: 69.36709594726562
# epoch 57
# Average loss: 72.85435776747028
# Validation loss: 69.70652770996094
# epoch 58
# Average loss: 72.87566698313432
# Validation loss: 72.10247802734375
# epoch 59
# Average loss: 72.70191974632205
# Validation loss: 71.0037841796875
# epoch 60
# Average loss: 72.61544653428557
# Validation loss: 74.93843078613281
# epoch 61
# Average loss: 72.61626348530079
# Validation loss: 72.20166778564453
# epoch 62
# Average loss: 72.58003030059703
# Validation loss: 72.26225280761719
# epoch 63
# Average loss: 72.59386985621977
# Validation loss: 72.3995590209961
# epoch 64
# Average loss: 72.85918567047058
# Validation loss: 72.31688690185547
# epoch 65
# Average loss: 72.36954093296553
# Validation loss: 74.3248291015625
# epoch 66
# Average loss: 72.15657788253225
# Validation loss: 70.32769012451172
# epoch 67
# Average loss: 72.21863191505442
# Validation loss: 75.139404296875
# epoch 68
# Average loss: 71.95433418984281
# Validation loss: 72.16546630859375
# epoch 69
# Average loss: 71.94959386651048
# Validation loss: 68.44617462158203
# epoch 70
# Average loss: 71.90988642589933
# Validation loss: 69.67514038085938
# epoch 71
# Average loss: 71.862057299539
# Validation loss: 69.32405853271484
# epoch 72
# Average loss: 71.8930207467377
# Validation loss: 67.88285827636719
# epoch 73
# Average loss: 71.79197939496423
# Validation loss: 74.06785583496094
# epoch 74
# Average loss: 71.78166565900847
# Validation loss: 68.57881164550781
# epoch 75
# Average loss: 71.57860363764611
# Validation loss: 70.77519226074219
# epoch 76
# Average loss: 71.49906575127217
# Validation loss: 74.96440124511719
# epoch 77
# Average loss: 71.54276958005845
# Validation loss: 68.30696105957031
# epoch 78
# Average loss: 71.55435627172763
# Validation loss: 73.81475067138672
# epoch 79
# Average loss: 71.33981462238009
# Validation loss: 67.99837493896484
# epoch 80
# Average loss: 71.1724929778819
# Validation loss: 69.04271697998047
# epoch 81
# Average loss: 71.19082212313583
# Validation loss: 70.50788116455078
# epoch 82
# Average loss: 71.1588053582225
# Validation loss: 75.0456314086914
# epoch 83
# Average loss: 71.09089234431681
# Validation loss: 75.43004608154297
# epoch 84
# Average loss: 71.15316365313886
# Validation loss: 73.09085083007812
# epoch 85
# Average loss: 70.94053714480049
# Validation loss: 72.59365844726562
# epoch 86
# Average loss: 70.9743657263956
# Validation loss: 68.6154556274414
# epoch 87
# Average loss: 70.87260071071393
# Validation loss: 69.01829528808594
# epoch 88
# Average loss: 70.78771928374395
# Validation loss: 67.31927490234375
# epoch 89
# Average loss: 70.95240566587313
# Validation loss: 69.09873962402344
# epoch 90
# Average loss: 70.77402556302901
# Validation loss: 67.81222534179688
# epoch 91
# Average loss: 70.76069908649487
# Validation loss: 71.68816375732422
# epoch 92
# Average loss: 70.68383326563129
# Validation loss: 69.14156341552734
# epoch 93
# Average loss: 70.73464423367594
# Validation loss: 68.75029754638672
# epoch 94
# Average loss: 70.72831822633263
# Validation loss: 70.72871398925781
# epoch 95
# Average loss: 70.82833460077842
# Validation loss: 72.63433837890625
# epoch 96
# Average loss: 70.685660433356
# Validation loss: 68.15924072265625
# epoch 97
# Average loss: 70.4974206311719
# Validation loss: 70.22135162353516
# epoch 98
# Average loss: 70.46399255435057
# Validation loss: 68.98760223388672
# epoch 99
# Average loss: 70.43549767293933
# Validation loss: 67.69255828857422
# epoch 100
# Average loss: 70.35548705316657
# Validation loss: 66.69853210449219
# epoch 101
# Average loss: 70.42579797870063
# Validation loss: 65.50189208984375
# epoch 102
# Average loss: 70.3069322948156
# Validation loss: 68.29524993896484
# epoch 103
# Average loss: 70.30079994678304
# Validation loss: 69.90135955810547
# epoch 104
# Average loss: 70.3776112517634
# Validation loss: 70.72476196289062
# epoch 105
# Average loss: 70.45096384868752
# Validation loss: 71.01603698730469
# epoch 106
# Average loss: 70.34733958553758
# Validation loss: 69.48652648925781
# epoch 107
# Average loss: 70.25967096023528
# Validation loss: 68.93901062011719
# epoch 108
# Average loss: 70.23011528239621
# Validation loss: 67.39532470703125
# epoch 109
# Average loss: 70.22541176220525
# Validation loss: 71.46138000488281
# epoch 110
# Average loss: 70.09719630913695
# Validation loss: 68.75301361083984
# epoch 111
# Average loss: 70.09712191562122
# Validation loss: 70.2172622680664
# epoch 112
# Average loss: 70.02970879465185
# Validation loss: 69.00495910644531
# epoch 113
# Average loss: 70.78982926491334
# Validation loss: 70.00311279296875
# epoch 114
# Average loss: 71.35340875812425
# Validation loss: 71.2093505859375
# epoch 115
# Average loss: 70.3541271082099
# Validation loss: 73.37701416015625
# epoch 116
# Average loss: 70.2892673773806
# Validation loss: 70.3253173828125
# epoch 117
# Average loss: 70.416089428091
# Validation loss: 69.44246673583984
# epoch 118
# Average loss: 70.25828582382356
# Validation loss: 69.00479888916016
# epoch 119
# Average loss: 69.9947576188407
# Validation loss: 68.1959457397461
# epoch 120
# Average loss: 69.84141447658455
# Validation loss: 69.8634262084961
# epoch 121
# Average loss: 69.85595348870163
# Validation loss: 68.52058410644531
# epoch 122
# Average loss: 69.90778746599153
# Validation loss: 71.28618621826172
# epoch 123
# Average loss: 69.84695088925837
# Validation loss: 68.05876922607422
# epoch 124
# Average loss: 69.82172794488109
# Validation loss: 70.35569763183594
# epoch 125
# Average loss: 69.77720519699717
# Validation loss: 69.30721282958984
# epoch 126
# Average loss: 70.46364932077539
# Validation loss: 72.44821166992188
# epoch 127
# Average loss: 70.96356233153215
# Validation loss: 69.22513580322266
# epoch 128
# Average loss: 70.67399442796503
# Validation loss: 71.33772277832031
# epoch 129
# Average loss: 70.21216459939289
# Validation loss: 69.06153106689453
# epoch 130
# Average loss: 70.04781731786578
# Validation loss: 70.72161865234375
# epoch 131
# Average loss: 70.09182383772924
# Validation loss: 68.12125396728516
# epoch 132
# Average loss: 69.9369877081444
# Validation loss: 68.36595916748047
# epoch 133
# Average loss: 69.87301420483172
# Validation loss: 70.82548522949219
# epoch 134
# Average loss: 69.83584440970122
# Validation loss: 71.73157501220703
# epoch 135
# Average loss: 69.81186962319882
# Validation loss: 71.51583099365234
# epoch 136
# Average loss: 69.80002314464933
# Validation loss: 70.72026824951172
# epoch 137
# Average loss: 69.78937148894096
# Validation loss: 69.51839447021484
# epoch 138
# Average loss: 69.8279431491838
# Validation loss: 69.73758697509766
# epoch 139
# Average loss: 69.7177452939213
# Validation loss: 68.46137237548828
# epoch 140
# Average loss: 69.71812946361095
# Validation loss: 69.29400634765625
# epoch 141
# Average loss: 69.64402781451531
# Validation loss: 66.78369903564453
# epoch 142
# Average loss: 69.63908064571997
# Validation loss: 69.46507263183594
# epoch 143
# Average loss: 69.61618397477076
# Validation loss: 69.32242584228516
# epoch 144
# Average loss: 69.67582120207325
# Validation loss: 68.41751861572266
# epoch 145
# Average loss: 69.59592827362958
# Validation loss: 66.5920639038086
# epoch 146
# Average loss: 69.58520281483021
# Validation loss: 67.10760498046875
# epoch 147
# Average loss: 69.52634101200373
# Validation loss: 67.77040100097656
# epoch 148
# Average loss: 69.58082560270556
# Validation loss: 68.1225814819336
# epoch 149
# Average loss: 69.55998715235792
# Validation loss: 67.08421325683594
# epoch 150
# Average loss: 69.51490763395556
# Validation loss: 69.46849060058594
# epoch 151
# Average loss: 69.5318610895934
# Validation loss: 68.06615447998047
# epoch 152
# Average loss: 69.47205834655885
# Validation loss: 68.06806945800781
# epoch 153
# Average loss: 69.49174822400242
# Validation loss: 70.33815002441406
# epoch 154
# Average loss: 69.44199510026199
# Validation loss: 69.93502807617188
# epoch 155
# Average loss: 69.44008566669186
# Validation loss: 66.38391876220703
# epoch 156
# Average loss: 69.44772517224658
# Validation loss: 69.0291748046875
# epoch 157
# Average loss: 69.38783957294186
# Validation loss: 70.91471862792969
# epoch 158
# Average loss: 69.44564510593007
# Validation loss: 71.9686050415039
# epoch 159
# Average loss: 69.32149059414047
# Validation loss: 67.40746307373047
# epoch 160
# Average loss: 69.3983705851975
# Validation loss: 70.86463165283203
# epoch 161
# Average loss: 69.36536800779676
# Validation loss: 70.03106689453125
# epoch 162
# Average loss: 69.36735852636286
# Validation loss: 68.8100814819336
# epoch 163
# Average loss: 69.42230856855855
# Validation loss: 71.40512084960938
# epoch 164
# Average loss: 69.32037173928103
# Validation loss: 66.93954467773438
# epoch 165
# Average loss: 69.32473222270505
# Validation loss: 67.89324951171875
# epoch 166
# Average loss: 69.28738274164903
# Validation loss: 68.35901641845703
# epoch 167
# Average loss: 69.31796300319931
# Validation loss: 67.64616394042969
# epoch 168
# Average loss: 69.27696548455764
# Validation loss: 68.46763610839844
# epoch 169
# Average loss: 69.2849342503023
# Validation loss: 70.00468444824219
# epoch 170
# Average loss: 69.24969101105904
# Validation loss: 70.69757843017578
# epoch 171
# Average loss: 69.30447219178255
# Validation loss: 70.63824462890625
# epoch 172
# Average loss: 69.3111247040004
# Validation loss: 68.10765075683594
# epoch 173
# Average loss: 69.31908008678457
# Validation loss: 66.99716186523438
# epoch 174
# Average loss: 69.28376835827288
# Validation loss: 66.99837493896484
# epoch 175
# Average loss: 69.25735944742543
# Validation loss: 68.52604675292969
# epoch 176
# Average loss: 69.64458143610187
# Validation loss: 69.49855041503906
# epoch 177
# Average loss: 69.61556461923115
# Validation loss: 67.10670471191406
# epoch 178
# Average loss: 70.25140088107113
# Validation loss: 66.81745910644531
# epoch 179
# Average loss: 69.5426770801844
# Validation loss: 69.38284301757812
# epoch 180
# Average loss: 69.56594119212264
# Validation loss: 67.1846923828125
# epoch 181
# Average loss: 69.49393555081116
# Validation loss: 68.42884063720703
# epoch 182
# Average loss: 69.30720762954705
# Validation loss: 66.16376495361328
# epoch 183
# Average loss: 69.20718692531993
# Validation loss: 66.49481964111328
# epoch 184
# Average loss: 69.28413757053607
# Validation loss: 71.51030731201172
# epoch 185
# Average loss: 69.22207389441002
# Validation loss: 69.13699340820312
# epoch 186
# Average loss: 69.17385311964682
# Validation loss: 70.85234069824219
# epoch 187
# Average loss: 69.10486474550332
# Validation loss: 67.48823547363281
# epoch 188
# Average loss: 69.24679084479544
# Validation loss: 69.71720123291016
# epoch 189
# Average loss: 69.23467828150191
# Validation loss: 66.96642303466797
# epoch 190
# Average loss: 69.12164264818874
# Validation loss: 67.79178619384766
# epoch 191
# Average loss: 69.20339462729243
# Validation loss: 68.67144012451172
# epoch 192
# Average loss: 69.19098035696292
# Validation loss: 73.05347442626953
# epoch 193
# Average loss: 69.13383393477932
# Validation loss: 68.56879425048828
# epoch 194
# Average loss: 69.1553427140014
# Validation loss: 68.47787475585938
# epoch 195
# Average loss: 69.16025248923066
# Validation loss: 68.71870422363281
# epoch 196
# Average loss: 69.52282837848901
# Validation loss: 72.50862121582031
# epoch 197
# Average loss: 69.37971454145254
# Validation loss: 69.917236328125
# epoch 198
# Average loss: 69.24296646702439
# Validation loss: 67.06586456298828
# epoch 199
# Average loss: 69.2556682741964
# Validation loss: 68.52044677734375
# epoch 200
# Average loss: 69.1055827019725
# Validation loss: 69.84611511230469
# epoch 201
# Average loss: 69.08976168096282
# Validation loss: 67.1778793334961
# epoch 202
# Average loss: 69.07839384005945
# Validation loss: 68.93501281738281
# epoch 203
# Average loss: 69.123127172763
# Validation loss: 70.4315414428711
# epoch 204
# Average loss: 69.10594994615326
# Validation loss: 67.13018035888672
# epoch 205
# Average loss: 69.10011064559401
# Validation loss: 65.9219741821289
# epoch 206
# Average loss: 69.134685327237
# Validation loss: 70.43325805664062
# epoch 207
# Average loss: 69.07612168889813
# Validation loss: 70.47473907470703
# epoch 208
# Average loss: 69.1328498935661
# Validation loss: 67.17943572998047
# epoch 209
# Average loss: 69.13932271985843
# Validation loss: 69.5535888671875
# epoch 210
# Average loss: 69.13511555005542
# Validation loss: 66.55551147460938
# epoch 211
# Average loss: 69.012421158618
# Validation loss: 68.78890228271484
# epoch 212
# Average loss: 69.0538876713019
# Validation loss: 69.41796875
# epoch 213
# Average loss: 69.04739181844518
# Validation loss: 68.66093444824219
# epoch 214
# Average loss: 69.06411500843913
# Validation loss: 69.27176666259766
# epoch 215
# Average loss: 69.085020964014
# Validation loss: 70.97929382324219
# epoch 216
# Average loss: 69.15279936108172
# Validation loss: 68.23651123046875
# epoch 217
# Average loss: 69.03641956210953
# Validation loss: 66.90376281738281
# epoch 218
# Average loss: 69.03380260290709
# Validation loss: 68.54325866699219
# epoch 219
# Average loss: 68.99484204957679
# Validation loss: 68.09918212890625
# epoch 220
# Average loss: 69.12155861106912
# Validation loss: 67.55381774902344
# epoch 221
# Average loss: 69.03552014844065
# Validation loss: 66.51507568359375
# epoch 222
# Average loss: 69.09836367722818
# Validation loss: 65.71662902832031
# epoch 223
# Average loss: 69.11698085134522
# Validation loss: 67.35693359375
# epoch 224
# Average loss: 69.14058288303607
# Validation loss: 70.40296936035156
# epoch 225
# Average loss: 69.09883749307235
# Validation loss: 68.27933502197266
# epoch 226
# Average loss: 68.99619215412132
# Validation loss: 67.102783203125
# epoch 227
# Average loss: 68.91757533032296
# Validation loss: 66.47332763671875
# epoch 228
# Average loss: 69.081295580789
# Validation loss: 66.98399353027344
# epoch 229
# Average loss: 69.0020519227378
# Validation loss: 68.931640625
# epoch 230
# Average loss: 69.31375543977983
# Validation loss: 76.78885650634766
# epoch 231
# Average loss: 70.53971098315951
# Validation loss: 71.98869323730469
# epoch 232
# Average loss: 69.49535276696645
# Validation loss: 68.65081024169922
# epoch 233
# Average loss: 69.26337351370415
# Validation loss: 69.29890441894531
# epoch 234
# Average loss: 69.80251552423418
# Validation loss: 71.21686553955078
# epoch 235
# Average loss: 69.36524106648025
# Validation loss: 74.27520751953125
# epoch 236
# Average loss: 69.10383583201079
# Validation loss: 65.75962829589844
# epoch 237
# Average loss: 69.07918067941354
# Validation loss: 70.08441162109375
# epoch 238
# Average loss: 69.1270080344997
# Validation loss: 71.2310562133789
# epoch 239
# Average loss: 69.05217603001562
# Validation loss: 67.10945892333984
# epoch 240
# Average loss: 69.0109134106711
# Validation loss: 69.63096618652344
# epoch 241
# Average loss: 69.18534121038644
# Validation loss: 69.0477523803711
# epoch 242
# Average loss: 69.10824650153668
# Validation loss: 68.23524475097656
# epoch 243
# Average loss: 69.06403215216899
# Validation loss: 66.567626953125
# epoch 244
# Average loss: 69.1620706037762
# Validation loss: 69.96227264404297
# epoch 245
# Average loss: 69.25022691990377
# Validation loss: 67.1540756225586
# epoch 246
# Average loss: 68.95251115509119
# Validation loss: 68.44558715820312
# epoch 247
# Average loss: 68.97359227000202
# Validation loss: 71.98289489746094
# epoch 248
# Average loss: 68.99224142545849
# Validation loss: 70.14810180664062
# epoch 249
# Average loss: 69.00496015813935
# Validation loss: 69.56774139404297
# epoch 250
# Average loss: 68.92018599166163
# Validation loss: 64.97713470458984
# epoch 251
# Average loss: 68.90462790646413
# Validation loss: 69.59902954101562
# epoch 252
# Average loss: 68.79139900745668
# Validation loss: 71.35652923583984
# epoch 253
# Average loss: 68.93916047114318
# Validation loss: 72.51470947265625
# epoch 254
# Average loss: 68.90681700454705
# Validation loss: 68.9081039428711
# epoch 255
# Average loss: 68.83697389220576
# Validation loss: 68.85240173339844
# epoch 256
# Average loss: 68.82615121013453
# Validation loss: 71.2212905883789
# epoch 257
# Average loss: 68.8764703543808
# Validation loss: 65.43791198730469
# epoch 258
# Average loss: 69.11133265158958
# Validation loss: 70.78276062011719
# epoch 259
# Average loss: 69.31404868406136
# Validation loss: 69.14631652832031
# epoch 260
# Average loss: 68.93942045483172
# Validation loss: 70.24444580078125
# epoch 261
# Average loss: 68.90718149341244
# Validation loss: 66.46188354492188
# epoch 262
# Average loss: 68.92943893118954
# Validation loss: 68.08043670654297
# epoch 263
# Average loss: 68.85288800351421
# Validation loss: 68.37940216064453
# epoch 264
# Average loss: 68.8140557691581
# Validation loss: 70.83183288574219
# epoch 265
# Average loss: 68.84720614954907
# Validation loss: 69.84217834472656
# epoch 266
# Average loss: 68.85572086135883
# Validation loss: 67.69535827636719
# epoch 267
# Average loss: 68.82388771853587
# Validation loss: 69.3021240234375
# epoch 268
# Average loss: 68.81583747417876
# Validation loss: 68.43318176269531
# epoch 269
# Average loss: 68.89909759484583
# Validation loss: 66.47843933105469
# epoch 270
# Average loss: 68.84079669551089
# Validation loss: 70.42581939697266
# epoch 271
# Average loss: 68.8642698178028
# Validation loss: 66.10918426513672
# epoch 272
# Average loss: 68.80535704164147
# Validation loss: 74.54100036621094
# epoch 273
# Average loss: 68.81121090601069
# Validation loss: 66.78529357910156
# epoch 274
# Average loss: 68.81319650437072
# Validation loss: 71.14102935791016
# epoch 275
# Average loss: 68.79429740244609
# Validation loss: 67.22161102294922
# epoch 276
# Average loss: 68.73908816379485
# Validation loss: 67.61537170410156
# epoch 277
# Average loss: 68.82058035601824
# Validation loss: 69.67842864990234
# epoch 278
# Average loss: 68.78696688583233
# Validation loss: 71.79537963867188
# epoch 279
# Average loss: 68.75633879987907
# Validation loss: 69.04110717773438
# epoch 280
# Average loss: 68.71358102831519
# Validation loss: 70.46241760253906
# epoch 281
# Average loss: 68.77397262161175
# Validation loss: 65.40057373046875
# epoch 282
# Average loss: 68.73574399813583
# Validation loss: 67.83731842041016
# epoch 283
# Average loss: 68.71550227037989
# Validation loss: 67.56230926513672
# epoch 284
# Average loss: 68.78141728700625
# Validation loss: 72.54741668701172
# epoch 285
# Average loss: 68.76988235590488
# Validation loss: 70.653564453125
# epoch 286
# Average loss: 68.79930262967301
# Validation loss: 70.80873107910156
# epoch 287
# Average loss: 68.79155684766727
# Validation loss: 66.22944641113281
# epoch 288
# Average loss: 68.74599987246826
# Validation loss: 66.93243408203125
# epoch 289
# Average loss: 68.7695967871448
# Validation loss: 66.31932067871094
# epoch 290
# Average loss: 68.75119580688231
# Validation loss: 71.10618591308594
# epoch 291
# Average loss: 68.78175107378577
# Validation loss: 72.28775787353516
# epoch 292
# Average loss: 68.69593953106106
# Validation loss: 72.16056060791016
# epoch 293
# Average loss: 68.79138601811266
# Validation loss: 67.36749267578125
# epoch 294
# Average loss: 68.74294285003526
# Validation loss: 67.52362823486328
# epoch 295
# Average loss: 68.75100490288695
# Validation loss: 70.23081970214844
# epoch 296
# Average loss: 68.7476762850791
# Validation loss: 67.10164642333984
# epoch 297
# Average loss: 68.73917731792876
# Validation loss: 67.529052734375
# epoch 298
# Average loss: 68.64957013143642
# Validation loss: 70.62242126464844
# epoch 299
# Average loss: 68.7754760397773
# Validation loss: 72.746826171875
# epoch 300
# Average loss: 68.73743910752972
# Validation loss: 66.90275573730469
# epoch 301
# Average loss: 68.60953480829302
# Validation loss: 70.49020385742188
# epoch 302
# Average loss: 68.7237408602252
# Validation loss: 70.63650512695312
# epoch 303
# Average loss: 68.72317326525342
# Validation loss: 69.30049133300781
# epoch 304
# Average loss: 68.76228536093058
# Validation loss: 68.43965911865234
# epoch 305
# Average loss: 68.75970874741787
# Validation loss: 67.27108764648438
# epoch 306
# Average loss: 68.77210294330663
# Validation loss: 70.32479095458984
# epoch 307
# Average loss: 68.91864537673821
# Validation loss: 70.38751220703125
# epoch 308
# Average loss: 68.9177333673418
# Validation loss: 67.37001037597656
# epoch 309
# Average loss: 68.75021019120314
# Validation loss: 70.31383514404297
# epoch 310
# Average loss: 68.842592570725
# Validation loss: 65.16029357910156
# epoch 311
# Average loss: 68.90585579308998
# Validation loss: 65.19409942626953
# epoch 312
# Average loss: 68.8071731881046
# Validation loss: 67.97537231445312
# epoch 313
# Average loss: 68.75296412894247
# Validation loss: 66.87782287597656
# epoch 314
# Average loss: 68.74887681535922
# Validation loss: 67.54154205322266
# epoch 315
# Average loss: 68.82071024945839
# Validation loss: 65.50161743164062
# epoch 316
# Average loss: 68.7551662163694
# Validation loss: 69.7466049194336
# epoch 317
# Average loss: 68.83026371517282
# Validation loss: 69.51045989990234
# epoch 318
# Average loss: 68.87885330858273
# Validation loss: 68.65108489990234
# epoch 319
# Average loss: 68.84448645644397
# Validation loss: 66.08534240722656
# epoch 320
# Average loss: 68.75850644586356
# Validation loss: 67.77607727050781
# epoch 321
# Average loss: 68.76390410872632
# Validation loss: 67.59978485107422
# epoch 322
# Average loss: 68.72498527874345
# Validation loss: 66.70573425292969
# epoch 323
# Average loss: 68.6673840327111
# Validation loss: 64.80178833007812
# epoch 324
# Average loss: 68.67540259094115
# Validation loss: 69.9184341430664
# epoch 325
# Average loss: 68.70541387986195
# Validation loss: 68.83809661865234
# epoch 326
# Average loss: 68.77473741844267
# Validation loss: 71.07624816894531
# epoch 327
# Average loss: 68.70657977189137
# Validation loss: 66.56581115722656
# epoch 328
# Average loss: 68.7158886049602
# Validation loss: 66.4390869140625
# epoch 329
# Average loss: 68.68789696222541
# Validation loss: 69.56531524658203
# epoch 330
# Average loss: 68.63871773132054
# Validation loss: 69.16315460205078
# epoch 331
# Average loss: 68.70795920086407
# Validation loss: 71.12368774414062
# epoch 332
# Average loss: 68.69595035551441
# Validation loss: 69.15701293945312
# epoch 333
# Average loss: 68.64725409203699
# Validation loss: 66.32295227050781
# epoch 334
# Average loss: 68.62432494772773
# Validation loss: 69.07687377929688
# epoch 335
# Average loss: 68.7275376848423
# Validation loss: 70.51390075683594
# epoch 336
# Average loss: 68.67415974688886
# Validation loss: 71.49295043945312
# epoch 337
# Average loss: 68.62192821694882
# Validation loss: 67.06726837158203
# epoch 338
# Average loss: 68.68491945032245
# Validation loss: 68.94395446777344
# epoch 339
# Average loss: 68.65918323004837
# Validation loss: 69.90821075439453
# epoch 340
# Average loss: 68.64257576330108
# Validation loss: 66.27313995361328
# epoch 341
# Average loss: 68.6833514790533
# Validation loss: 69.19291687011719
# epoch 342
# Average loss: 68.71100284033656
# Validation loss: 73.10324096679688
# epoch 343
# Average loss: 68.65619115433545
# Validation loss: 67.20340728759766
# epoch 344
# Average loss: 68.60145150015114
# Validation loss: 70.9708251953125
# epoch 345
# Average loss: 68.62175207357164
# Validation loss: 67.824951171875
# epoch 346
# Average loss: 68.61498068917523
# Validation loss: 67.69681549072266
# epoch 347
# Average loss: 68.63407718976723
# Validation loss: 68.53372192382812
# epoch 348
# Average loss: 68.66387986195083
# Validation loss: 69.96930694580078
# epoch 349
# Average loss: 68.7315094719871
# Validation loss: 71.92913818359375
# epoch 350
# Average loss: 68.72432813602126
# Validation loss: 67.0816879272461
# epoch 351
# Average loss: 68.67858655469065
# Validation loss: 66.83492279052734
# epoch 352
# Average loss: 68.6282361179338
# Validation loss: 67.84868621826172
# epoch 353
# Average loss: 68.64082023377671
# Validation loss: 66.61009979248047
# epoch 354
# Average loss: 68.61709440970122
# Validation loss: 68.47928619384766
# epoch 355
# Average loss: 68.62113035633313
# Validation loss: 69.71609497070312
# epoch 356
# Average loss: 68.61265736787082
# Validation loss: 70.94374084472656
# epoch 357
# Average loss: 68.6861191933696
# Validation loss: 66.92761993408203
# epoch 358
# Average loss: 68.58096553336608
# Validation loss: 68.89153289794922
# epoch 359
# Average loss: 68.63533676252015
# Validation loss: 66.3956298828125
# epoch 360
# Average loss: 68.67098345866083
# Validation loss: 70.20073699951172
# epoch 361
# Average loss: 68.66736927209291
# Validation loss: 69.26048278808594
# epoch 362
# Average loss: 68.57081121208687
# Validation loss: 68.46056365966797
# epoch 363
# Average loss: 68.62056768156741
# Validation loss: 66.63902282714844
# epoch 364
# Average loss: 68.63614033057488
# Validation loss: 69.49763488769531
# epoch 365
# Average loss: 68.66324062877872
# Validation loss: 72.48979187011719
# epoch 366
# Average loss: 68.63275542560963
# Validation loss: 70.93777465820312
# epoch 367
# Average loss: 68.64487802612354
# Validation loss: 68.26300811767578
# epoch 368
# Average loss: 68.60048458125503
# Validation loss: 68.1279525756836
# epoch 369
# Average loss: 68.60578561127066
# Validation loss: 67.55833435058594
# epoch 370
# Average loss: 68.61129958780482
# Validation loss: 69.3031005859375
# epoch 371
# Average loss: 68.56293947280582
# Validation loss: 68.60379791259766
# epoch 372
# Average loss: 68.61916758772924
# Validation loss: 73.49555206298828
# epoch 373
# Average loss: 68.59891444509522
# Validation loss: 70.49757385253906
# epoch 374
# Average loss: 68.63891158743954
# Validation loss: 65.89698791503906
# epoch 375
# Average loss: 68.5988026580134
# Validation loss: 70.17333221435547
# epoch 376
# Average loss: 68.59564880592502
# Validation loss: 67.35599517822266
# epoch 377
# Average loss: 68.56406619999497
# Validation loss: 69.35453796386719
# epoch 378
# Average loss: 68.64793249004937
# Validation loss: 69.05339813232422
# epoch 379
# Average loss: 68.61360854210751
# Validation loss: 65.8648910522461
# epoch 380
# Average loss: 68.62461937285873
# Validation loss: 67.15886688232422
# epoch 381
# Average loss: 68.59350989394397
# Validation loss: 70.0983657836914
# epoch 382
# Average loss: 68.60348000270808
# Validation loss: 67.46880340576172
# epoch 383
# Average loss: 68.60991090884472
# Validation loss: 68.4944839477539
# epoch 384
# Average loss: 68.6241747830386
# Validation loss: 66.14540100097656
# epoch 385
# Average loss: 68.61706114910822
# Validation loss: 67.51478576660156
# epoch 386
# Average loss: 68.60446069818117
# Validation loss: 67.69204711914062
# epoch 387
# Average loss: 68.52217969852126
# Validation loss: 65.6905517578125
# epoch 388
# Average loss: 68.60215528642685
# Validation loss: 67.5653076171875
# epoch 389
# Average loss: 68.5599446417775
# Validation loss: 67.19882202148438
# epoch 390
# Average loss: 68.59277402792473
# Validation loss: 68.82071685791016
# epoch 391
# Average loss: 68.59014447299477
# Validation loss: 70.03120422363281
# epoch 392
# Average loss: 68.53295829554615
# Validation loss: 71.03589630126953
# epoch 393
# Average loss: 68.64348678865629
# Validation loss: 65.69146728515625
# epoch 394
# Average loss: 68.58788078458787
# Validation loss: 68.51516723632812
# epoch 395
# Average loss: 68.56118669859684
# Validation loss: 71.82292175292969
# epoch 396
# Average loss: 68.63225297416616
# Validation loss: 68.20790100097656
# epoch 397
# Average loss: 68.57575779045747
# Validation loss: 66.18424224853516
# epoch 398
# Average loss: 68.6187580297763
# Validation loss: 67.36841583251953
# epoch 399
# Average loss: 68.6267016040659
# Validation loss: 66.72312927246094
# epoch 400
# Average loss: 68.86433181239923
# Validation loss: 68.00367736816406
# epoch 401
# Average loss: 68.67509694774033
# Validation loss: 70.67646789550781
# epoch 402
# Average loss: 68.61193508162032
# Validation loss: 68.54381561279297
# epoch 403
# Average loss: 68.640264053683
# Validation loss: 67.47178649902344
# epoch 404
# Average loss: 68.5773104106837
# Validation loss: 68.45555114746094
# epoch 405
# Average loss: 68.59097500377872
# Validation loss: 66.45689392089844
# epoch 406
# Average loss: 68.56333131801694
# Validation loss: 66.84996032714844
# epoch 407
# Average loss: 68.53448178815246
# Validation loss: 65.79945373535156
# epoch 408
# Average loss: 68.56314415337818
# Validation loss: 66.15076446533203
# epoch 409
# Average loss: 68.63022703011639
# Validation loss: 76.08415222167969
# epoch 410
# Average loss: 68.55560659449314
# Validation loss: 67.32711791992188
# epoch 411
# Average loss: 68.52069143459039
# Validation loss: 70.68463897705078
# epoch 412
# Average loss: 68.58103166093561
# Validation loss: 72.163330078125
# epoch 413
# Average loss: 68.54707377632506
# Validation loss: 67.3648910522461
# epoch 414
# Average loss: 68.60005022546352
# Validation loss: 66.88843536376953
# epoch 415
# Average loss: 68.57090174387848
# Validation loss: 71.09477996826172
# epoch 416
# Average loss: 68.60166464347793
# Validation loss: 69.54169464111328
# epoch 417
# Average loss: 68.5118031807361
# Validation loss: 67.56989288330078
# epoch 418
# Average loss: 68.47443362523931
# Validation loss: 70.08001708984375
# epoch 419
# Average loss: 68.49851862435762
# Validation loss: 68.34526824951172
# epoch 420
# Average loss: 68.48279187449617
# Validation loss: 68.89051055908203
# epoch 421
# Average loss: 68.57378754314037
# Validation loss: 67.46244049072266
# epoch 422
# Average loss: 68.55048013338876
# Validation loss: 66.72350311279297
# epoch 423
# Average loss: 68.55551881801694
# Validation loss: 67.34078979492188
# epoch 424
# Average loss: 68.5168249398554
# Validation loss: 67.62335205078125
# epoch 425
# Average loss: 68.52991032629232
# Validation loss: 69.82063293457031
# epoch 426
# Average loss: 68.49079724657396
# Validation loss: 67.82152557373047
# epoch 427
# Average loss: 68.56537497480855
# Validation loss: 66.74723815917969
# epoch 428
# Average loss: 68.54073202432235
# Validation loss: 66.35337829589844
# epoch 429
# Average loss: 68.53728177902056
# Validation loss: 69.9736557006836
# epoch 430
# Average loss: 68.57932867921201
# Validation loss: 67.8385238647461
# epoch 431
# Average loss: 68.50884495604092
# Validation loss: 67.88273620605469
# epoch 432
# Average loss: 68.5389701969342
# Validation loss: 70.66287231445312
# epoch 433
# Average loss: 68.47215242089884
# Validation loss: 68.32626342773438
# epoch 434
# Average loss: 68.60451993746221
# Validation loss: 67.82852172851562
# epoch 435
# Average loss: 68.50128909398931
# Validation loss: 66.67514038085938
# epoch 436
# Average loss: 68.49516855445133
# Validation loss: 66.41844177246094
# epoch 437
# Average loss: 68.52954603423518
# Validation loss: 68.87996673583984
# epoch 438
# Average loss: 68.52449632834542
# Validation loss: 72.58729553222656
# epoch 439
# Average loss: 68.57492686605703
# Validation loss: 72.25151062011719
# epoch 440
# Average loss: 68.5164515946191
# Validation loss: 67.5372085571289
# epoch 441
# Average loss: 68.4717157034084
# Validation loss: 64.83106231689453
# epoch 442
# Average loss: 68.51760981112706
# Validation loss: 69.34053802490234
# epoch 443
# Average loss: 68.57479362687677
# Validation loss: 73.3576889038086
# epoch 444
# Average loss: 68.48549779102429
# Validation loss: 66.2783203125
# epoch 445
# Average loss: 68.46410316058294
# Validation loss: 69.7067642211914
# epoch 446
# Average loss: 68.51768833761588
# Validation loss: 68.02136993408203
# epoch 447
# Average loss: 68.52874226937223
# Validation loss: 67.5518798828125
# epoch 448
# Average loss: 68.47416045539853
# Validation loss: 68.32486724853516
# epoch 449
# Average loss: 68.49657868550987
# Validation loss: 66.2185287475586
# epoch 450
# Average loss: 68.46295793341899
# Validation loss: 69.90313720703125
# epoch 451
# Average loss: 68.42468069830713
# Validation loss: 69.3775405883789
# epoch 452
# Average loss: 68.53754353398327
# Validation loss: 65.7402572631836
# epoch 453
# Average loss: 68.46422065510379
# Validation loss: 69.83013916015625
# epoch 454
# Average loss: 68.49691089782345
# Validation loss: 72.41578674316406
# epoch 455
# Average loss: 68.5019088431454
# Validation loss: 73.34429931640625
# epoch 456
# Average loss: 68.46174677549375
# Validation loss: 68.81463623046875
# epoch 457
# Average loss: 68.43166483241384
# Validation loss: 67.3725357055664
# epoch 458
# Average loss: 68.42127138911981
# Validation loss: 67.34423065185547
# epoch 459
# Average loss: 68.46303960883968
# Validation loss: 66.1913833618164
# epoch 460
# Average loss: 68.45758802051844
# Validation loss: 69.386474609375
# epoch 461
# Average loss: 68.43806464284815
# Validation loss: 70.34680938720703
# epoch 462
# Average loss: 68.69275359922914
# Validation loss: 68.23905181884766
# epoch 463
# Average loss: 68.89411401652559
# Validation loss: 68.86856079101562
# epoch 464
# Average loss: 68.73407880359483
# Validation loss: 68.1415023803711
# epoch 465
# Average loss: 68.70498129534462
# Validation loss: 68.04842376708984
# epoch 466
# Average loss: 68.52056724858927
# Validation loss: 67.31402587890625
# epoch 467
# Average loss: 68.58605578175383
# Validation loss: 66.35601806640625
# epoch 468
# Average loss: 68.47783663656288
# Validation loss: 69.94898986816406
# epoch 469
# Average loss: 68.4681330061593
# Validation loss: 65.95561218261719
# epoch 470
# Average loss: 68.50048296742744
# Validation loss: 65.62846374511719
# epoch 471
# Average loss: 68.41422899977327
# Validation loss: 71.93710327148438
# epoch 472
# Average loss: 68.46227855136537
# Validation loss: 68.28588104248047
# epoch 473
# Average loss: 68.49913542139006
# Validation loss: 68.52479553222656
# epoch 474
# Average loss: 68.48765441574717
# Validation loss: 66.03060913085938
# epoch 475
# Average loss: 68.45243420306832
# Validation loss: 67.89837646484375
# epoch 476
# Average loss: 68.52533630592502
# Validation loss: 72.01460266113281
# epoch 477
# Average loss: 68.52775862177549
# Validation loss: 71.06867218017578
# epoch 478
# Average loss: 68.40345296125554
# Validation loss: 66.54457092285156
# epoch 479
# Average loss: 68.47840226345224
# Validation loss: 67.25086212158203
# epoch 480
# Average loss: 68.50568854544538
# Validation loss: 70.87189483642578
# epoch 481
# Average loss: 68.4693666002242
# Validation loss: 66.61778259277344
# epoch 482
# Average loss: 68.46293884301944
# Validation loss: 73.04088592529297
# epoch 483
# Average loss: 68.49214203729595
# Validation loss: 67.87174987792969
# epoch 484
# Average loss: 68.48311247512343
# Validation loss: 68.33120727539062
# epoch 485
# Average loss: 68.42951411193823
# Validation loss: 70.14895629882812
# epoch 486
# Average loss: 68.44188193552247
# Validation loss: 66.75284576416016
# epoch 487
# Average loss: 68.46787341608726
# Validation loss: 68.40143585205078
# epoch 488
# Average loss: 68.45422181233626
# Validation loss: 68.78977966308594
# epoch 489
# Average loss: 68.40233115427247
# Validation loss: 71.56517028808594
# epoch 490
# Average loss: 68.43024604179263
# Validation loss: 68.40463256835938
# epoch 491
# Average loss: 68.41801755844418
# Validation loss: 67.56344604492188
# epoch 492
# Average loss: 68.48204793933898
# Validation loss: 68.43116760253906
# epoch 493
# Average loss: 68.44336842817916
# Validation loss: 66.38301849365234
# epoch 494
# Average loss: 68.47075291748538
# Validation loss: 67.98967742919922
# epoch 495
# Average loss: 68.47467471533656
# Validation loss: 67.65887451171875
# epoch 496
# Average loss: 68.51783161401653
# Validation loss: 67.45543670654297
# epoch 497
# Average loss: 68.39189756209694
# Validation loss: 69.83301544189453
# epoch 498
# Average loss: 68.43970307146816
# Validation loss: 68.05138397216797
# epoch 499
# Average loss: 68.44612138187726
# Validation loss: 66.98931884765625
# epoch 500
# Average loss: 68.4400872411578
# Validation loss: 67.01451873779297
# epoch 501
# Average loss: 68.42933009623135
# Validation loss: 67.83517456054688
# epoch 502
# Average loss: 68.45894914632457
# Validation loss: 69.89775085449219
# epoch 503
# Average loss: 68.4384765625
# Validation loss: 69.46534729003906
# epoch 504
# Average loss: 68.48294636896665
# Validation loss: 70.9492416381836
# epoch 505
# Average loss: 68.47455761443219
# Validation loss: 67.18724822998047
# epoch 506
# Average loss: 68.42786741737203
# Validation loss: 72.13815307617188
# epoch 507
# Average loss: 68.44894223441908
# Validation loss: 72.26702117919922
# epoch 508
# Average loss: 68.46354757091395
# Validation loss: 66.602783203125
# epoch 509
# Average loss: 68.45758861094316
# Validation loss: 65.54227447509766
# epoch 510
# Average loss: 68.41709059162132
# Validation loss: 67.16204071044922
# epoch 511
# Average loss: 68.42666531262596
# Validation loss: 66.81243896484375
# epoch 512
# Average loss: 68.53238420590236
# Validation loss: 72.75050354003906
# epoch 513
# Average loss: 68.54072080625252
# Validation loss: 65.95701599121094
# epoch 514
# Average loss: 68.46149289286075
# Validation loss: 73.56151580810547
# epoch 515
# Average loss: 68.47633695775393
# Validation loss: 67.890625
# epoch 516
# Average loss: 68.38176803865629
# Validation loss: 68.19915008544922
# epoch 517
# Average loss: 68.42845725167523
# Validation loss: 65.86608123779297
# epoch 518
# Average loss: 68.449539941052
# Validation loss: 66.69684600830078
# epoch 519
# Average loss: 68.4288097352378
# Validation loss: 67.16503143310547
# epoch 520
# Average loss: 68.43474133886286
# Validation loss: 68.8341293334961
# epoch 521
# Average loss: 68.44850669777811
# Validation loss: 66.97367858886719
# epoch 522
# Average loss: 68.47749212373412
# Validation loss: 72.1590576171875
# epoch 523
# Average loss: 68.43642916635177
# Validation loss: 72.98404693603516
# epoch 524
# Average loss: 68.42774854519347
# Validation loss: 68.93622589111328
# epoch 525
# Average loss: 68.51779343321745
# Validation loss: 69.44039154052734
# epoch 526
# Average loss: 68.45400670092704
# Validation loss: 70.15998840332031
# epoch 527
# Average loss: 68.41659207634271
# Validation loss: 68.57467651367188
# epoch 528
# Average loss: 68.39460013288493
# Validation loss: 66.86891174316406
# epoch 529
# Average loss: 68.39458871800686
# Validation loss: 67.1853256225586
# epoch 530
# Average loss: 68.41587333264057
# Validation loss: 67.7406005859375
# epoch 531
# Average loss: 68.37490395757759
# Validation loss: 66.88887023925781
# epoch 532
# Average loss: 68.43149321562626
# Validation loss: 66.88785552978516
# epoch 533
# Average loss: 68.40787898182437
# Validation loss: 69.09654998779297
# epoch 534
# Average loss: 68.40947667113815
# Validation loss: 72.88153076171875
# epoch 535
# Average loss: 68.40810235917976
# Validation loss: 68.62467956542969
# epoch 536
# Average loss: 68.39090368047158
# Validation loss: 70.2547378540039
# epoch 537
# Average loss: 68.42207771248992
# Validation loss: 69.24516296386719
# epoch 538
# Average loss: 68.42042137431983
# Validation loss: 69.47920989990234
# epoch 539
# Average loss: 68.41773218649234
# Validation loss: 66.68892669677734
# epoch 540
# Average loss: 68.42556633539903
# Validation loss: 71.60450744628906
# epoch 541
# Average loss: 68.34870425389208
# Validation loss: 65.29598236083984
# epoch 542
# Average loss: 68.404082747632
# Validation loss: 71.93899536132812
# epoch 543
# Average loss: 68.45405924872783
# Validation loss: 69.64881896972656
# epoch 544
# Average loss: 68.40646078162787
# Validation loss: 70.13946533203125
# epoch 545
# Average loss: 68.3844097956973
# Validation loss: 68.57426452636719
# epoch 546
# Average loss: 68.39528561599406
# Validation loss: 65.21601867675781
# epoch 547
# Average loss: 68.38860535381399
# Validation loss: 67.61625671386719
# epoch 548
# Average loss: 68.35680330669337
# Validation loss: 67.44071960449219
# epoch 549
# Average loss: 68.38523501265871
# Validation loss: 70.08267211914062
# epoch 550
# Average loss: 68.41963689666466
# Validation loss: 67.40831756591797
# epoch 551
# Average loss: 68.42645630227227
# Validation loss: 68.08599853515625
# epoch 552
# Average loss: 68.42258902030431
# Validation loss: 67.14503479003906
# epoch 553
# Average loss: 68.4381382491309
# Validation loss: 68.24696350097656
# epoch 554
# Average loss: 68.43253078868148
# Validation loss: 71.03775024414062
# epoch 555
# Average loss: 68.43862987612101
# Validation loss: 68.96473693847656
# epoch 556
# Average loss: 68.36956238506399
# Validation loss: 72.21636962890625
# epoch 557
# Average loss: 68.39691341696897
# Validation loss: 68.40031433105469
# epoch 558
# Average loss: 68.38294947853689
# Validation loss: 65.24024200439453
# epoch 559
# Average loss: 68.42155026639963
# Validation loss: 67.15933990478516
# epoch 560
# Average loss: 68.40396033290507
# Validation loss: 67.73676300048828
# epoch 561
# Average loss: 68.41858653107366
# Validation loss: 67.1263656616211
# epoch 562
# Average loss: 68.40567138376663
# Validation loss: 67.41339111328125
# epoch 563
# Average loss: 68.44673699806026
# Validation loss: 66.61122131347656
# epoch 564
# Average loss: 68.4799416975262
# Validation loss: 66.38455200195312
# epoch 565
# Average loss: 68.49357893427549
# Validation loss: 71.46772766113281
# epoch 566
# Average loss: 68.41941607781641
# Validation loss: 70.94129943847656
# epoch 567
# Average loss: 68.42103580965336
# Validation loss: 65.8136215209961
# epoch 568
# Average loss: 68.40640469127872
# Validation loss: 66.98950958251953
# epoch 569
# Average loss: 68.34051919588876
# Validation loss: 66.44532775878906
# epoch 570
# Average loss: 68.43901798197551
# Validation loss: 67.56100463867188
# epoch 571
# Average loss: 68.37092941511739
# Validation loss: 67.10807037353516
# epoch 572
# Average loss: 68.38578725658756
# Validation loss: 70.02145385742188
# epoch 573
# Average loss: 68.41988763036578
# Validation loss: 67.26494598388672
# epoch 574
# Average loss: 68.470789917435
# Validation loss: 67.91736602783203
# epoch 575
# Average loss: 68.5174281571191
# Validation loss: 68.27271270751953
# epoch 576
# Average loss: 69.65753574824919
# Validation loss: 67.39311218261719
# epoch 577
# Average loss: 69.22212545816959
# Validation loss: 69.21810150146484
# epoch 578
# Average loss: 68.99716202514107
# Validation loss: 66.79228973388672
# epoch 579
# Average loss: 68.72966577237001
# Validation loss: 69.55549621582031
# epoch 580
# Average loss: 68.54200045344619
# Validation loss: 72.90290832519531
# epoch 581
# Average loss: 68.51022005523227
# Validation loss: 67.33267974853516
# epoch 582
# Average loss: 68.50967588044135
# Validation loss: 70.9879379272461
# epoch 583
# Average loss: 68.5093363862228
# Validation loss: 67.63739013671875
# epoch 584
# Average loss: 68.45690371825877
# Validation loss: 71.47195434570312
# epoch 585
# Average loss: 68.47752508911478
# Validation loss: 67.89276123046875
# epoch 586
# Average loss: 68.52791016412233
# Validation loss: 69.25350189208984
# epoch 587
# Average loss: 68.41986460380139
# Validation loss: 66.38773345947266
# epoch 588
# Average loss: 68.4401075124068
# Validation loss: 72.90621948242188
# epoch 589
# Average loss: 68.43200727875605
# Validation loss: 67.6506118774414
# epoch 590
# Average loss: 68.4308953121851
# Validation loss: 66.92290496826172
# epoch 591
# Average loss: 68.4374626064339
# Validation loss: 71.11815643310547
# epoch 592
# Average loss: 68.5159125368425
# Validation loss: 69.92996215820312
# epoch 593
# Average loss: 68.40538857032195
# Validation loss: 66.74407958984375
# epoch 594
# Average loss: 68.45211419286578
# Validation loss: 72.41629028320312
# epoch 595
# Average loss: 68.41898034436718
# Validation loss: 66.06100463867188
# epoch 596
# Average loss: 68.4223203770531
# Validation loss: 67.95596313476562
# epoch 597
# Average loss: 68.41203025808646
# Validation loss: 67.09461975097656
# epoch 598
# Average loss: 68.42936335682437
# Validation loss: 69.6659164428711
# epoch 599
# Average loss: 68.40867881052247
# Validation loss: 67.20025634765625
# epoch 600
# Average loss: 68.35213777049324
# Validation loss: 67.63838958740234
# epoch 601
# Average loss: 68.36539713541667
# Validation loss: 67.91921997070312
# epoch 602
# Average loss: 68.37918434004686
# Validation loss: 65.96286010742188
# epoch 603
# Average loss: 68.38336927051844
# Validation loss: 66.70066833496094
# epoch 604
# Average loss: 68.42716973215185
# Validation loss: 72.09498596191406
# epoch 605
# Average loss: 68.42565726080713
# Validation loss: 67.4994888305664
# epoch 606
# Average loss: 68.43642818231056
# Validation loss: 65.91197967529297
# epoch 607
# Average loss: 68.35245797750403
# Validation loss: 66.18822479248047
# epoch 608
# Average loss: 68.34500603020456
# Validation loss: 70.0774154663086
# epoch 609
# Average loss: 68.38934318791566
# Validation loss: 67.34529113769531
# epoch 610
# Average loss: 68.40950934130643
# Validation loss: 69.57917785644531
# epoch 611
# Average loss: 68.39875298361297
# Validation loss: 67.13908386230469
# epoch 612
# Average loss: 68.39548025934603
# Validation loss: 67.36712646484375
# epoch 613
# Average loss: 68.45229545325725
# Validation loss: 69.24332427978516
# epoch 614
# Average loss: 68.43060797215085
# Validation loss: 69.04698181152344
# epoch 615
# Average loss: 68.38609821361095
# Validation loss: 68.38471984863281
# epoch 616
# Average loss: 68.38192076185258
# Validation loss: 68.49635314941406
# epoch 617
# Average loss: 68.35610778636386
# Validation loss: 67.77792358398438
# epoch 618
# Average loss: 68.4095756656842
# Validation loss: 70.27384185791016
# epoch 619
# Average loss: 68.38409785463271
# Validation loss: 68.01478576660156
# epoch 620
# Average loss: 68.39458182971836
# Validation loss: 66.19209289550781
# epoch 621
# Average loss: 68.39724858140619
# Validation loss: 70.82445526123047
# epoch 622
# Average loss: 68.36403089259623
# Validation loss: 68.281005859375
# epoch 623
# Average loss: 68.41150300880442
# Validation loss: 71.07864379882812
# epoch 624
# Average loss: 68.35784147017331
# Validation loss: 66.45890045166016
# epoch 625
# Average loss: 68.3439733773554
# Validation loss: 67.41239166259766
# epoch 626
# Average loss: 68.35601253117443
# Validation loss: 68.45125579833984
# epoch 627
# Average loss: 68.31435413045395
# Validation loss: 65.60177612304688
# epoch 628
# Average loss: 68.36369690900847
# ...
# Validation loss: 67.21903228759766
# epoch 793
# Average loss: 68.3413233543682
# Validation loss: 70.49893188476562
# epoch 794
# Average loss: 68.29282232466747
# Validation loss: 66.77611541748047
# epoch 795
# Average loss: 68.30315101804968
# Validation loss: 71.05953979492188
# epoch 796
# Average loss: 68.29214530431278
# Validation loss: 67.21281433105469
# epoch 797
# Average loss: 68.29765593510682
# Validation loss: 68.59364318847656
# epoch 798
# Average loss: 68.24903839492644
# Validation loss: 69.2459945678711
# epoch 799
# Average loss: 68.29103196008414
# Validation loss: 67.25425720214844
# epoch 800
# Average loss: 68.29988045867341
# Validation loss: 68.12483215332031
# epoch 801
# Average loss: 68.27261169261386
# Validation loss: 69.6650390625
# epoch 802
# Average loss: 68.29945377840336
# Validation loss: 69.30123901367188
# epoch 803
# Average loss: 68.30472961696393
# Validation loss: 71.53083801269531
# epoch 804
# Average loss: 68.2591689024083
# Validation loss: 65.79008483886719
# epoch 805
# Average loss: 68.26393441719569
# Validation loss: 67.96200561523438
# epoch 806
# Average loss: 68.23581799803506
# Validation loss: 68.74403381347656
# epoch 807
# Average loss: 68.24079724657396
# Validation loss: 65.58171081542969
# epoch 808
# Average loss: 68.31159566612504
# Validation loss: 67.03335571289062
# epoch 809
# Average loss: 68.292768399209
# Validation loss: 73.7352294921875
# epoch 810
# Average loss: 68.26195649435711
# Validation loss: 66.95917510986328
# epoch 811
# Average loss: 68.25830924400444
# Validation loss: 69.37787628173828
# epoch 812
# Average loss: 68.3434209366183
# Validation loss: 65.95529174804688
# epoch 813
# Average loss: 68.34679108096533
# Validation loss: 71.3294906616211
# epoch 814
# Average loss: 68.29219450637343
# Validation loss: 68.80847930908203
# epoch 815
# Average loss: 68.28067669758917
# Validation loss: 70.00538635253906
# epoch 816
# Average loss: 68.29657506423821
# Validation loss: 65.85015869140625
# epoch 817
# Average loss: 68.2283471571443
# Validation loss: 66.38390350341797
# epoch 818
# Average loss: 68.26702666830411
# Validation loss: 70.81460571289062
# epoch 819
# Average loss: 68.27195592754937
# Validation loss: 68.42926025390625
# epoch 820
# Average loss: 68.31015463617241
# Validation loss: 68.89042663574219
# epoch 821
# Average loss: 68.25760191518037
# Validation loss: 66.01493072509766
# epoch 822
# Average loss: 68.28518104783858
# Validation loss: 68.28475952148438
# epoch 823
# Average loss: 68.31228193646714
# Validation loss: 66.68035888671875
# epoch 824
# Average loss: 68.25353133029776
# Validation loss: 66.52202606201172
# epoch 825
# Average loss: 68.29593091086004
# Validation loss: 67.62700653076172
# epoch 826
# Average loss: 68.31460919393642
# Validation loss: 66.69915771484375
# epoch 827
# Average loss: 68.28456720292976
# Validation loss: 67.13763427734375
# epoch 828
# Average loss: 68.23716987385379
# Validation loss: 66.27981567382812
# epoch 829
# Average loss: 68.33048177870566
# Validation loss: 66.55751037597656
# epoch 830
# Average loss: 68.31311168001814
# Validation loss: 68.24310302734375
# epoch 831
# Average loss: 68.34337409625655
# Validation loss: 72.23209381103516
# epoch 832
# Average loss: 68.24385800836356
# Validation loss: 72.32665252685547
# epoch 833
# Average loss: 68.26516938891828
# Validation loss: 67.22270202636719
# epoch 834
# Average loss: 68.2536866120012
# Validation loss: 69.06007385253906
# epoch 835
# Average loss: 68.25855623834896
# Validation loss: 67.18218994140625
# epoch 836
# Average loss: 68.27638588428304
# Validation loss: 67.03912353515625
# epoch 837
# Average loss: 68.33649702583384
# Validation loss: 65.544189453125
# epoch 838
# Average loss: 68.30976377500252
# Validation loss: 66.63823699951172
# epoch 839
# Average loss: 68.29471975293481
# Validation loss: 70.45028686523438
# epoch 840
# Average loss: 68.22320121202388
# Validation loss: 67.6407699584961
# epoch 841
# Average loss: 68.27233852277307
# Validation loss: 68.83450317382812
# epoch 842
# Average loss: 68.27149834838522
# Validation loss: 68.44808959960938
# epoch 843
# Average loss: 68.2776741910394
# Validation loss: 70.91875457763672
# epoch 844
# Average loss: 68.26806837433243
# Validation loss: 69.49345397949219
# epoch 845
# Average loss: 68.26329400317412
# Validation loss: 69.12592315673828
# epoch 846
# Average loss: 68.28516353190498
# Validation loss: 65.83256530761719
# epoch 847
# Average loss: 68.43748701065599
# Validation loss: 68.17533111572266
# epoch 848
# Average loss: 68.26560807449113
# Validation loss: 65.99392700195312
# epoch 849
# Average loss: 68.1766936530129
# Validation loss: 71.2820816040039
# epoch 850
# Average loss: 68.26395114589631
# Validation loss: 66.84559631347656
# epoch 851
# Average loss: 68.28396260800837
# Validation loss: 67.37606048583984
# epoch 852
# Average loss: 68.26753561441959
# Validation loss: 66.77928161621094
# epoch 853
# Average loss: 68.3036467780129
# Validation loss: 65.77212524414062
# epoch 854
# Average loss: 68.25242133180924
# Validation loss: 66.16961669921875
# epoch 855
# Average loss: 68.2694952340916
# Validation loss: 66.5497817993164
# epoch 856
# Average loss: 68.26323220538593
# Validation loss: 67.39421081542969
# epoch 857
# Average loss: 68.23675244357113
# Validation loss: 68.32766723632812
# epoch 858
# Average loss: 68.28779879427398
# Validation loss: 69.4688720703125
# epoch 859
# Average loss: 68.28336686945788
# Validation loss: 68.85302734375
# epoch 860
# Average loss: 68.28176012696494
# Validation loss: 69.59292602539062
# epoch 861
# Average loss: 68.34119129603738
# Validation loss: 66.48027038574219
# epoch 862
# Average loss: 68.26348746567665
# Validation loss: 67.87905883789062
# epoch 863
# Average loss: 68.24676840865578
# Validation loss: 67.78388977050781
# epoch 864
# Average loss: 68.269022697501
# Validation loss: 68.04119110107422
# epoch 865
# Average loss: 68.23483671213724
# Validation loss: 67.20980834960938
# epoch 866
# Average loss: 68.24393751889359
# Validation loss: 69.0709228515625
# epoch 867
# Average loss: 68.24315284443017
# Validation loss: 65.83602142333984
# epoch 868
# Average loss: 68.23991554564692
# Validation loss: 68.03773498535156
# epoch 869
# Average loss: 68.25019484016022
# Validation loss: 67.52963256835938
# epoch 870
# Average loss: 68.23545921660873
# Validation loss: 70.34139251708984
# epoch 871
# Average loss: 68.28574943004332
# Validation loss: 67.02151489257812
# epoch 872
# Average loss: 68.2886208623035
# Validation loss: 67.88323211669922
# epoch 873
# Average loss: 68.23443876587062
# Validation loss: 66.73480987548828
# epoch 874
# Average loss: 68.26669071663392
# Validation loss: 69.04115295410156
# epoch 875
# Average loss: 68.26810006045949
# Validation loss: 67.80546569824219
# epoch 876
# Average loss: 68.25903704088573
# Validation loss: 72.06221008300781
# epoch 877
# Average loss: 68.29134724688886
# Validation loss: 70.77755737304688
# epoch 878
# Average loss: 68.27056213157498
# Validation loss: 70.58353424072266
# epoch 879
# Average loss: 68.24081318804161
# Validation loss: 74.45850372314453
# epoch 880
# Average loss: 68.26189095721232
# Validation loss: 68.40425109863281
# epoch 881
# Average loss: 68.27614715588473
# Validation loss: 68.85430145263672
# epoch 882
# Average loss: 68.28665041817816
# Validation loss: 68.22498321533203
# epoch 883
# Average loss: 68.25085769032144
# Validation loss: 74.98634338378906
# epoch 884
# Average loss: 68.23076199428154
# Validation loss: 68.56904602050781
# epoch 885
# Average loss: 68.31206466016727
# Validation loss: 67.0359115600586
# epoch 886
# Average loss: 68.2319816149612
# Validation loss: 67.84406280517578
# epoch 887
# Average loss: 68.25245892218359
# Validation loss: 69.09095001220703
# epoch 888
# Average loss: 68.29881257714884
# Validation loss: 67.81128692626953
# epoch 889
# Average loss: 68.28648746095324
# Validation loss: 68.118896484375
# epoch 890
# Average loss: 68.29158577847895
# Validation loss: 70.28668212890625
# epoch 891
# Average loss: 68.29396440289953
# Validation loss: 67.2550048828125
# epoch 892
# Average loss: 68.32074429728436
# Validation loss: 66.8006362915039
# epoch 893
# Average loss: 68.27232828874446
# Validation loss: 67.77365112304688
# epoch 894
# Average loss: 68.26684580152912
# Validation loss: 68.33470916748047
# epoch 895
# Average loss: 68.2543478876965
# Validation loss: 73.19932556152344
# epoch 896
# Average loss: 68.25862964782345
# Validation loss: 71.9570083618164
# epoch 897
# Average loss: 68.26808648069076
# Validation loss: 67.015869140625
# epoch 898
# Average loss: 68.2923964316304
# Validation loss: 69.6041488647461
# epoch 899
# Average loss: 68.22015934382557
# Validation loss: 68.42704772949219
# epoch 900
# Average loss: 68.27106143408656
# Validation loss: 66.60548400878906
# epoch 901
# Average loss: 68.21842506959139
# Validation loss: 66.96820068359375
# epoch 902
# Average loss: 68.22497681598901
# Validation loss: 70.38552856445312
# epoch 903
# Average loss: 68.23677724140971
# Validation loss: 68.17219543457031
# epoch 904
# Average loss: 68.21905898894096
# Validation loss: 72.3358154296875
# epoch 905
# Average loss: 68.25933658303103
# Validation loss: 65.49382019042969
# epoch 906
# Average loss: 68.24815610357467
# Validation loss: 73.06668853759766
# epoch 907
# Average loss: 68.21498978171604
# Validation loss: 74.03400421142578
# epoch 908
# Average loss: 68.22668334026099
# Validation loss: 69.15750885009766
# epoch 909
# Average loss: 68.23465269643037
# Validation loss: 68.05046844482422
# epoch 910
# Average loss: 68.29229645304312
# Validation loss: 66.937255859375
# epoch 911
# Average loss: 68.2281113808696
# Validation loss: 67.53831481933594
# epoch 912
# Average loss: 68.28759372008514
# Validation loss: 67.38449096679688
# epoch 913
# Average loss: 68.22213805389711
# Validation loss: 71.88799285888672
# epoch 914
# Average loss: 68.22224019737504
# Validation loss: 72.03123474121094
# epoch 915
# Average loss: 68.27776806857113
# Validation loss: 66.22601318359375
# epoch 916
# Average loss: 68.19017659209996
# Validation loss: 68.09030151367188
# epoch 917
# Average loss: 68.24511679388351
# Validation loss: 65.82714080810547
# epoch 918
# Average loss: 68.26930570775393
# Validation loss: 69.18335723876953
# epoch 919
# Average loss: 68.31956049570486
# Validation loss: 70.42640686035156
# epoch 920
# Average loss: 68.24435357151854
# Validation loss: 66.96632385253906
# epoch 921
# Average loss: 68.19749608745214
# Validation loss: 67.90536499023438
# epoch 922
# Average loss: 68.2778491535671
# Validation loss: 68.08070373535156
# epoch 923
# Average loss: 68.23967248746725
# Validation loss: 68.18707275390625
# epoch 924
# Average loss: 68.23094266424829
# Validation loss: 73.3029556274414
# epoch 925
# Average loss: 68.19644119527156
# Validation loss: 67.27259826660156
# epoch 926
# Average loss: 68.21741406564894
# Validation loss: 68.36750793457031
# epoch 927
# Average loss: 68.23807578219468
# Validation loss: 68.10111999511719
# epoch 928
# Average loss: 68.2100213576305
# Validation loss: 67.87035369873047
# epoch 929
# Average loss: 68.2241063331318
# Validation loss: 70.95893096923828
# epoch 930
# Average loss: 68.2228717550257
# Validation loss: 66.20663452148438
# epoch 931
# Average loss: 68.20625936807235
# Validation loss: 65.93126678466797
# epoch 932
# Average loss: 68.24401210921755
# Validation loss: 67.66886138916016
# epoch 933
# Average loss: 68.17730533303103
# Validation loss: 71.67560577392578
# epoch 934
# Average loss: 68.25162602970073
# Validation loss: 67.64269256591797
# epoch 935
# Average loss: 68.28094553764863
# Validation loss: 72.09559631347656
# epoch 936
# Average loss: 68.24298004679312
# Validation loss: 66.83921813964844
# epoch 937
# Average loss: 68.21533262167473
# Validation loss: 68.67505645751953
# epoch 938
# Average loss: 68.23819485118148
# Validation loss: 71.28890991210938
# epoch 939
# Average loss: 68.26703827999043
# Validation loss: 68.870361328125
# epoch 940
# Average loss: 68.25097282314339
# Validation loss: 65.01463317871094
# epoch 941
# Average loss: 68.24163624011236
# Validation loss: 69.21446228027344
# epoch 942
# Average loss: 68.21200951449768
# Validation loss: 70.34963989257812
# epoch 943
# Average loss: 68.18095278019196
# Validation loss: 67.620361328125
# epoch 944
# Average loss: 68.22164032585147
# Validation loss: 69.08123016357422
# epoch 945
# Average loss: 68.33782567827993
# Validation loss: 70.72692108154297
# epoch 946
# Average loss: 68.2522101565649
# Validation loss: 68.00794219970703
# epoch 947
# Average loss: 68.22245471835953
# Validation loss: 70.60038757324219
# epoch 948
# Average loss: 68.22829205083636
# Validation loss: 67.04596710205078
# epoch 949
# Average loss: 68.27688912295949
# Validation loss: 70.1214828491211
# epoch 950
# Average loss: 68.2346371485792
# Validation loss: 69.36337280273438
# epoch 951
# Average loss: 68.21216951959896
# Validation loss: 69.90733337402344
# epoch 952
# Average loss: 68.25235303934905
# Validation loss: 65.51331329345703
# epoch 953
# Average loss: 68.17721243954051
# Validation loss: 66.51921844482422
# epoch 954
# Average loss: 68.26055856540961
# Validation loss: 67.52654266357422
# epoch 955
# Average loss: 68.21884663284713
# Validation loss: 66.6494369506836
# epoch 956
# Average loss: 68.26025685837364
# Validation loss: 68.36758422851562
# epoch 957
# Average loss: 68.24312037107013
# Validation loss: 67.53339385986328
# epoch 958
# Average loss: 68.17942102163946
# Validation loss: 68.78852081298828
# epoch 959
# Average loss: 68.259184056643
# Validation loss: 72.35125732421875
# epoch 960
# Average loss: 68.24709412629736
# Validation loss: 69.9964599609375
# epoch 961
# Average loss: 68.24895160249143
# Validation loss: 70.58868408203125
# epoch 962
# Average loss: 68.19779543278919
# Validation loss: 67.47224426269531
# epoch 963
# Average loss: 68.21611099827439
# Validation loss: 66.52055358886719
# epoch 964
# Average loss: 68.18263076726875
# Validation loss: 73.5917739868164
# epoch 965
# Average loss: 68.24181868135328
# Validation loss: 68.61687469482422
# epoch 966
# Average loss: 68.24546553808948
# Validation loss: 74.73799133300781
# epoch 967
# Average loss: 68.18655335235289
# Validation loss: 66.10295867919922
# epoch 968
# Average loss: 68.22136991132608
# Validation loss: 66.81443786621094
# epoch 969
# Average loss: 68.28692358801895
# Validation loss: 65.92256164550781
# epoch 970
# Average loss: 68.22360801466142
# Validation loss: 65.77014923095703
# epoch 971
# Average loss: 68.1756608033555
# Validation loss: 66.4709701538086
# epoch 972
# Average loss: 68.23410281420043
# Validation loss: 70.56178283691406
# epoch 973
# Average loss: 68.2227887019473
# Validation loss: 65.64868927001953
# epoch 974
# Average loss: 68.232281550723
# Validation loss: 67.79308319091797
# epoch 975
# Average loss: 68.23331066102378
# Validation loss: 67.74236297607422
# epoch 976
# Average loss: 68.23594946594115
# Validation loss: 67.69636535644531
# epoch 977
# Average loss: 68.20606216621321
# Validation loss: 70.14327239990234
# epoch 978
# Average loss: 68.22657017552146
# Validation loss: 71.01406860351562
# epoch 979
# Average loss: 68.20620071921604
# Validation loss: 66.81849670410156
# epoch 980
# Average loss: 68.20687301617292
# Validation loss: 67.3939208984375
# epoch 981
# Average loss: 68.19349517268742
# Validation loss: 68.15876007080078
# epoch 982
# Average loss: 68.23985945529776
# Validation loss: 66.7135009765625
# epoch 983
# Average loss: 68.17344946594115
# Validation loss: 66.94617462158203
# epoch 984
# Average loss: 68.2196037541566
# Validation loss: 67.19303894042969
# epoch 985
# Average loss: 68.23835072330965
# Validation loss: 72.06782531738281
# epoch 986
# Average loss: 68.21372253344165
# Validation loss: 64.70970916748047
# epoch 987
# Average loss: 68.23443355045218
# Validation loss: 68.65193176269531
# epoch 988
# Average loss: 68.22170940554464
# Validation loss: 68.85542297363281
# epoch 989
# Average loss: 68.23178893969165
# Validation loss: 68.16119384765625
# epoch 990
# Average loss: 68.25997994917624
# Validation loss: 67.72484588623047
# epoch 991
# Average loss: 68.2129510451305
# Validation loss: 71.0486831665039
# epoch 992
# Average loss: 68.21873996277962
# Validation loss: 66.36627197265625
# epoch 993
# Average loss: 68.282079743551
# Validation loss: 72.25761413574219
# epoch 994
# Average loss: 68.28824535217655
# Validation loss: 66.75460815429688
# epoch 995
# Average loss: 68.22602422945637
# Validation loss: 65.75730895996094
# epoch 996
# Average loss: 68.20319171799426
# Validation loss: 70.51973724365234
# epoch 997
# Average loss: 68.18452996681026
# Validation loss: 68.32572937011719
# epoch 998
# Average loss: 68.20509485370063
# Validation loss: 69.5809555053711
# epoch 999
# Average loss: 68.21236613103335
# Validation loss: 69.22188568115234
# epoch 1000
# Average loss: 68.16494361050232
# Validation loss: 67.19776153564453

# %%
plt.plot(list(range(len(VAL_LOSS_LIST))), VAL_LOSS_LIST, c='y', label="validation")
plt.plot(list(range(len(LOSS_LIST))), LOSS_LIST, c='b', label="training")
plt.legend()
plt.show();

# %%
NUM_PLOTS = 25

samples = np.random.choice(len(test_normal_dataset), replace=False, size=NUM_PLOTS)
fig, axes = plt.subplots(nrows=int(np.sqrt(NUM_PLOTS)), ncols=int(np.sqrt(NUM_PLOTS)))
fig.tight_layout()
fig.set_size_inches(50, 30)
ANOMALY_THRESHOLD = 0.05
for i, ax in enumerate(axes.flat):
    outputs = model.forward(test_normal_dataset[i])
    log_probs = outputs["px"].log_prob(test_normal_dataset[i].view(-1)).exp().detach().numpy()
    idx = log_probs < ANOMALY_THRESHOLD
    anom = np.arange(len(test_normal_dataset[i]))[idx.squeeze()]
    
    mu = outputs["px"].mu.view(-1).detach().numpy()
    sigma = outputs["px"].sigma.view(-1).detach().numpy()
    ax.plot(mu, c="r", linewidth=5)
    ax.fill_between(list(range(len(mu))), mu-sigma, mu+sigma, facecolor='red', alpha=0.5)
    ax.plot(test_normal_dataset[i].view(-1), c="b", linewidth=5)
    ax.scatter(anom, test_normal_dataset[i].view(-1)[anom], c="r", s=400, label="anomaly")
    
    ax.set_title(f"Sample {samples[i]}", fontdict={"size": 26})
    plt.setp(ax.get_xticklabels(), fontsize=20)
    plt.setp(ax.get_yticklabels(), fontsize=20)
